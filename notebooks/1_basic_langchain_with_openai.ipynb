# %%
5+5
# Out:
# 10

# %%
#####LOad env
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_openai import ChatOpenAI
llm = ChatOpenAI(model="gpt-4")
res=llm.invoke("What is the capital of France?")
res.content
# Out:
# 'The capital of France is Paris.'

# %%
from langchain_openai import ChatOpenAI
llm = ChatOpenAI(model="gpt-4")

prompt = [("system","You are a python developer"),("user", "How to sort an array")]
res=llm.invoke(prompt)
res.content

# %%
res=llm.invoke("What is the capital of France?")
res
# Out:
# AIMessage(content='The capital of France is Paris.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 80, 'prompt_tokens': 13, 'total_tokens': 93, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 64, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-mini-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DdtaTxqVzEaYzTQdRQTVY1xkZoOpm', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019e10f3-491a-7772-8f85-b368e8f0b75e-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 13, 'output_tokens': 80, 'total_tokens': 93, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 64}})

# %%
res
