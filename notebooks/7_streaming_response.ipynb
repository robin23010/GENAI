# %%
from dotenv import load_dotenv
load_dotenv()

from langchain_openai import ChatOpenAI
llm = ChatOpenAI(model="gpt-4", streaming=True)

response = llm.stream("how should I print a long response in next line by line? which I am getting from this code")

for chunk in response:
    print(chunk.content, end="")
# Out:
# Without knowing your specific code, it can be hard to provide an exact solution. However, if you have a long string response that you want to print each line individually, you can split the string on newline characters and print each line. Here's a general way to do it in python:
#
# ```python
# response = """This is a very long response
# That spans multiple lines
# And you want to print it
# Line by line"""
#
# # Split the response into lines
# lines = response.split('\n')
#
# # Print each line individually
# for line in lines:
#     print(line)
# ```
#
# This will print:
#
# ```
# This is a very long response
# That spans multiple lines
# And you want to print it
# Line by line
# ```
#
# If you are receiving a long string from an API or some other method, you would replace the `response` variable with your string. If you get the response as a list or a string with different separator, you just change the split argument. This is just a basic way to print lines from a single string one by one.
#
# Also, if your text is in some sort of complex structure or in JSON format, you need to parse the data appropriately before printing it out.
